# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Kamal singh\Downloads\Student_500_Dataset.csv")

# %%
df.head()
# Out:
#    StudentID       Name Gender  Age  Class  Maths  Science  English  \
# 0       1001  Student_1      M   17     12     38       70       66
# 1       1002  Student_2      M   17     12     46       89       39
# 2       1003  Student_3      M   15     10     99       38       60
# 3       1004  Student_4      F   15     10     70       35       55
# 4       1005  Student_5      F   16     11     54       62       78
#
#    Attendance      City
# 0          77  Gurugram
# 1          70     Noida
# 2          92      Agra
# 3          92      Agra
# 4          73     Noida

# %%
df.tail()
# Out:
#      StudentID         Name Gender  Age  Class  Maths  Science  English  \
# 495       1496  Student_496      F   15     10     97       54       41
# 496       1497  Student_497      M   16     11     72       96       60
# 497       1498  Student_498      M   15     10     72       45       95
# 498       1499  Student_499      F   16     11     95       97       68
# 499       1500  Student_500      F   15     10     83       82       58
#
#      Attendance   City
# 495          81  Delhi
# 496          73  Delhi
# 497          97  Noida
# 498          72   Agra
# 499          84  Delhi

# %%
df.shape
# Out:
# (500, 10)

# %%
df.columns
# Out:
# Index(['StudentID', 'Name', 'Gender', 'Age', 'Class', 'Maths', 'Science',
#        'English', 'Attendance', 'City'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   StudentID   500 non-null    int64
#  1   Name        500 non-null    object
#  2   Gender      500 non-null    object
#  3   Age         500 non-null    int64
#  4   Class       500 non-null    int64
#  5   Maths       500 non-null    int64
#  6   Science     500 non-null    int64
#  7   English     500 non-null    int64
#  8   Attendance  500 non-null    int64
#  9   City        500 non-null    object
# dtypes: int64(7), object(3)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#          StudentID         Age       Class       Maths     Science  \
# count   500.000000  500.000000  500.000000  500.000000  500.000000
# mean   1250.500000   16.014000   11.014000   67.342000   67.620000
# std     144.481833    0.804424    0.804424   19.042118   18.860622
# min    1001.000000   15.000000   10.000000   35.000000   35.000000
# 25%    1125.750000   15.000000   10.000000   51.000000   51.000000
# 50%    1250.500000   16.000000   11.000000   66.000000   68.000000
# 75%    1375.250000   17.000000   12.000000   83.000000   84.000000
# max    1500.000000   17.000000   12.000000  100.000000  100.000000
#
#           English  Attendance
# count  500.000000  500.000000
# mean    67.798000   84.970000
# std     18.622965    8.946574
# min     35.000000   70.000000
# 25%     52.000000   78.000000
# 50%     69.000000   84.000000
# 75%     83.000000   92.000000
# max    100.000000  100.000000

# %%
df.isnull().sum()
# Out:
# StudentID     0
# Name          0
# Gender        0
# Age           0
# Class         0
# Maths         0
# Science       0
# English       0
# Attendance    0
# City          0
# dtype: int64

# %%
df["City"] = df["City"].fillna(df["City"].mode()[0])

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df["Total"] = df["Maths"] + df["Science"] + df["English"]
print(df)
# Out:
#      StudentID         Name Gender  Age  Class  Maths  Science  English  \
# 0         1001    Student_1      M   17     12     38       70       66
# 1         1002    Student_2      M   17     12     46       89       39
# 2         1003    Student_3      M   15     10     99       38       60
# 3         1004    Student_4      F   15     10     70       35       55
# 4         1005    Student_5      F   16     11     54       62       78
# ..         ...          ...    ...  ...    ...    ...      ...      ...
# 495       1496  Student_496      F   15     10     97       54       41
# 496       1497  Student_497      M   16     11     72       96       60
# 497       1498  Student_498      M   15     10     72       45       95
# 498       1499  Student_499      F   16     11     95       97       68
# 499       1500  Student_500      F   15     10     83       82       58
#
#      Attendance      City  Total
# 0            77  Gurugram    174
# 1            70     Noida    174
# 2            92      Agra    197
# 3            92      Agra    160
# 4            73     Noida    194
# ..          ...       ...    ...
# 495          81     Delhi    192
# 496          73     Delhi    228
# 497          97     Noida    212
# 498          72      Agra    260
# 499          84     Delhi    223
#
# [500 rows x 11 columns]

# %%
df["Average"] = df["Total"] / 3
print(df)
# Out:
#      StudentID         Name Gender  Age  Class  Maths  Science  English  \
# 0         1001    Student_1      M   17     12     38       70       66
# 1         1002    Student_2      M   17     12     46       89       39
# 2         1003    Student_3      M   15     10     99       38       60
# 3         1004    Student_4      F   15     10     70       35       55
# 4         1005    Student_5      F   16     11     54       62       78
# ..         ...          ...    ...  ...    ...    ...      ...      ...
# 495       1496  Student_496      F   15     10     97       54       41
# 496       1497  Student_497      M   16     11     72       96       60
# 497       1498  Student_498      M   15     10     72       45       95
# 498       1499  Student_499      F   16     11     95       97       68
# 499       1500  Student_500      F   15     10     83       82       58
#
#      Attendance      City  Total    Average
# 0            77  Gurugram    174  58.000000
# 1            70     Noida    174  58.000000
# 2            92      Agra    197  65.666667
# 3            92      Agra    160  53.333333
# 4            73     Noida    194  64.666667
# ..          ...       ...    ...        ...
# 495          81     Delhi    192  64.000000
# 496          73     Delhi    228  76.000000
# 497          97     Noida    212  70.666667
# 498          72      Agra    260  86.666667
# 499          84     Delhi    223  74.333333
#
# [500 rows x 12 columns]

# %%
df[["Name","Total","Average"]]
# Out:
#             Name  Total    Average
# 0      Student_1    174  58.000000
# 1      Student_2    174  58.000000
# 2      Student_3    197  65.666667
# 3      Student_4    160  53.333333
# 4      Student_5    194  64.666667
# ..           ...    ...        ...
# 495  Student_496    192  64.000000
# 496  Student_497    228  76.000000
# 497  Student_498    212  70.666667
# 498  Student_499    260  86.666667
# 499  Student_500    223  74.333333
#
# [500 rows x 3 columns]

# %%
df.nlargest(1, "Total")
# Out:
#      StudentID         Name Gender  Age  Class  Maths  Science  English  \
# 438       1439  Student_439      M   16     11     98       93      100
#
#      Attendance   City  Total  Average
# 438          81  Delhi    291     97.0

# %%
df.nlargest(10, "Total")
# Out:
#      StudentID         Name Gender  Age  Class  Maths  Science  English  \
# 438       1439  Student_439      M   16     11     98       93      100
# 395       1396  Student_396      F   15     10     99       98       87
# 173       1174  Student_174      F   16     11     93       99       90
# 312       1313  Student_313      M   16     11    100       88       93
# 467       1468  Student_468      F   17     12     98       87       96
# 235       1236  Student_236      F   16     11    100       85       95
# 430       1431  Student_431      F   16     11     99       88       89
# 127       1128  Student_128      M   17     12     98       72      100
# 381       1382  Student_382      M   16     11     96       79       95
# 254       1255  Student_255      F   15     10     85       96       87
#
#      Attendance       City  Total    Average
# 438          81      Delhi    291  97.000000
# 395          91  Ghaziabad    284  94.666667
# 173          73      Noida    282  94.000000
# 312          88      Delhi    281  93.666667
# 467          71      Noida    281  93.666667
# 235          78      Delhi    280  93.333333
# 430          92       Agra    276  92.000000
# 127          92     Jaipur    270  90.000000
# 381          73  Ghaziabad    270  90.000000
# 254          94       Agra    268  89.333333

# %%
len(df)
# Out:
# 500

# %%
df.nsmallest(1, "Total")
# Out:
#      StudentID         Name Gender  Age  Class  Maths  Science  English  \
# 341       1342  Student_342      M   17     12     44       41       35
#
#      Attendance      City  Total  Average
# 341          83  Gurugram    120     40.0

# %%
df[["Maths", "Science", "English"]].mean()
# Out:
# Maths      67.342
# Science    67.620
# English    67.798
# dtype: float64

# %%
df["Attendance"].mean()
# Out:
# np.float64(84.97)

# %%
df["Attendance"].max()
# Out:
# 100

# %%
df["Attendance"].min()
# Out:
# 70

# %%
df.nlargest(1, "Attendance")
# Out:
#     StudentID        Name Gender  Age  Class  Maths  Science  English  \
# 44       1045  Student_45      F   17     12     36       73       48
#
#     Attendance      City  Total    Average
# 44         100  Gurugram    157  52.333333

# %%
df.nsmallest(1, "Attendance")
# Out:
#    StudentID       Name Gender  Age  Class  Maths  Science  English  \
# 1       1002  Student_2      M   17     12     46       89       39
#
#    Attendance   City  Total  Average
# 1          70  Noida    174     58.0

# %%
df["Class"].value_counts()
# Out:
# Class
# 11    177
# 12    165
# 10    158
# Name: count, dtype: int64

# %%
df.groupby("Gender")["Average"].mean()
# Out:
# Gender
# F    67.852540
# M    67.277056
# Name: Average, dtype: float64

# %%
df.groupby("Class")["Average"].mean()
# Out:
# Class
# 10    67.947257
# 11    68.007533
# 12    66.789899
# Name: Average, dtype: float64

# %%
df[["Attendance", "Average"]].corr()
# Out:
#             Attendance   Average
# Attendance    1.000000 -0.011634
# Average      -0.011634  1.000000

# %%
df["Result"] = np.where(df["Average"] >= 40, "Pass", "Fail")

# %%
df
# Out:
#      StudentID         Name Gender  Age  Class  Maths  Science  English  \
# 0         1001    Student_1      M   17     12     38       70       66
# 1         1002    Student_2      M   17     12     46       89       39
# 2         1003    Student_3      M   15     10     99       38       60
# 3         1004    Student_4      F   15     10     70       35       55
# 4         1005    Student_5      F   16     11     54       62       78
# ..         ...          ...    ...  ...    ...    ...      ...      ...
# 495       1496  Student_496      F   15     10     97       54       41
# 496       1497  Student_497      M   16     11     72       96       60
# 497       1498  Student_498      M   15     10     72       45       95
# 498       1499  Student_499      F   16     11     95       97       68
# 499       1500  Student_500      F   15     10     83       82       58
#
#      Attendance      City  Total    Average Result
# 0            77  Gurugram    174  58.000000   Pass
# 1            70     Noida    174  58.000000   Pass
# 2            92      Agra    197  65.666667   Pass
# 3            92      Agra    160  53.333333   Pass
# 4            73     Noida    194  64.666667   Pass
# ..          ...       ...    ...        ...    ...
# 495          81     Delhi    192  64.000000   Pass
# 496          73     Delhi    228  76.000000   Pass
# 497          97     Noida    212  70.666667   Pass
# 498          72      Agra    260  86.666667   Pass
# 499          84     Delhi    223  74.333333   Pass
#
# [500 rows x 13 columns]

# %%
df["Result"].value_counts()
# Out:
# Result
# Pass    500
# Name: count, dtype: int64

# %%
subject_avg = df[["Maths", "Science", "English"]].mean()

plt.figure(figsize=(6,4))
plt.bar(subject_avg.index, subject_avg.values)

plt.title("Average Marks by Subject")
plt.xlabel("Subjects")
plt.ylabel("Average Marks")

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.hist(df["Average"], bins=10)

plt.title("Distribution of Average Marks")
plt.xlabel("Average Marks")
plt.ylabel("Number of Students")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(x="City", data=df)

plt.title("Students by City")

plt.show()

# %%
city_avg = df.groupby("City")["Average"].mean()

plt.figure(figsize=(8,5))

plt.bar(city_avg.index, city_avg.values)

plt.title("Average Marks by City")
plt.xlabel("City")
plt.ylabel("Average Marks")

plt.show()

# %%
plt.figure(figsize=(6,5))

plt.scatter(df["Attendance"], df["Average"])

plt.title("Attendance vs Average Marks")
plt.xlabel("Attendance")
plt.ylabel("Average Marks")

plt.show()

# %%
plt.figure(figsize=(10,5))

plt.plot(df["Average"])

plt.title("Average Marks")
plt.xlabel("Student Index")
plt.ylabel("Average")

plt.show()

# %%
plt.figure(figsize=(5,5))

sns.boxplot(y=df["Average"])

plt.title("Average Marks")

plt.show()

# %%
gender = df["Gender"].value_counts()

plt.figure(figsize=(5,5))

plt.pie(gender.values,
        labels=gender.index,
        autopct="%1.1f%%")

plt.title("Gender Distribution")

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.heatmap(df.corr(numeric_only=True),
            annot=True)

plt.title("Correlation Matrix")

plt.show()
